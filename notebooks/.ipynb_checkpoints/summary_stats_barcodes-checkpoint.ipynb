# %%
library(ggplot2)
library(patchwork)
library(ggthemes)

# %%
samples <- c('KI_1_1',
             'KI_1_2',
             'KI_1_3',
             'KI_1_4',
             'KI_1_5')

# %%
d.ls <- lapply(samples,function(x){
    d <- read.delim(file = paste0('/data/proj/GCB_MB/spatial_cut-tag/Yale_Apr_2022_nano_Tn5/results/stats/',x,'/adaptors_stats.txt'),header = 0)
    return(d)
})

# %%
head(d.ls[[1]])
# Out:
#   V1     V2   V3   V4   V5   V6       V7       V8
# 1 read_1 8    None None 32   NACGTGAT CTCATACA None
# 2 read_2 8    None None 40   NACGTGAT AACTGTCT None
# 3 read_3 8    None None None NACGTGAT AACGTGAT None
# 4 read_4 None None None 23   None     None     None
# 5 read_5 None None None 33   None     None     None
# 6 read_6 None None None 5    None     None     None

# %%
options(repr.plot.width=15, repr.plot.height=10)

df.gg.ls <- lapply(1:length(d.ls), function(x){
    bcd.summary               <- sort(table(d.ls[[x]]$V8), decreasing= TRUE)
    bcd.summary.ggplot        <- data.frame(head(bcd.summary,10))
    bcd.summary.ggplot$sample <- samples[x]
    head(bcd.summary.ggplot)
})

df.gg      <- do.call('rbind',df.gg.ls[length(df.gg.ls):1])
df.gg$Var1 <- as.factor(df.gg$Var1)

ggplot(data = df.gg) + 
      geom_bar(aes(y = Var1, x = Freq, fill = Var1),stat='identity') + 
      ylab("Barcodes") + theme_base() + facet_wrap(~sample)
# Out:
#    Var1     Freq    sample
# 1  AGATGTGT 4824727 KI_1_5
# 2  None     3362768 KI_1_5
# 3  TATAGCCT 1982664 KI_1_5
# 4  ATAGAGGC  945365 KI_1_5
# 5  GATGTGTA  101429 KI_1_5
# 6  AGATGCTG   92408 KI_1_5
# 7  AGATGTGT 4631342 KI_1_4
# 8  None     4272369 KI_1_4
# 9  TATAGCCT 1996338 KI_1_4
# 10 ATAGAGGC  926796 KI_1_4
# 11 TGTCTCTT  131641 KI_1_4
# 12 AGATGCTG  123732 KI_1_4
# 13 None     4174320 KI_1_3
# 14 AGATGTGT 2797755 KI_1_3
# 15 TATAGCCT 1277100 KI_1_3
# 16 ATAGAGGC  562021 KI_1_3
# 17 TGTCTCTT  139849 KI_1_3
# 18 AGATGCTG  106600 KI_1_3
# 19 None     6250099 KI_1_2
# 20 AGATGTGT  850205 KI_1_2
# 21 TATAGCCT  439136 KI_1_2
# 22 ATAGAGGC  177030 KI_1_2
# 23 TGTCTCTT  156402 KI_1_2
# 24 AGATGCTG   51772 KI_1_2
# 25 None     6073028 KI_1_1
# 26 AGATGTGT  657855 KI_1_1
# 27 TATAGCCT  350108 KI_1_1
# 28 TGTCTCTT  158031 KI_1_1
# 29 ATAGAGGC  139097 KI_1_1
# 30 AGATGCTG   30587 KI_1_1
# plot without title

# %%
d.filter.ls <- lapply(d.ls,function(x){
    all.bcd.obs.log <- x$V2 != "None" & x$V3 != "None" & x$V4 != "None"
    P7_found.log    <- x$V5 != "None"
    all.bcd.obs <- which(all.bcd.obs.log)
    P7_found    <- which(P7_found.log)

    x$status              <- 'barcode missing'
    x$status[P7_found]    <- 'barcode missing P7 found'
    x$status[all.bcd.obs] <- 'all barcodes found'
    x$P7_distance           <- 0
    x$P7_distance[P7_found]    <- x$V5[P7_found]
    x$P7_distance[all.bcd.obs] <- 140
    x
    })

# %%
barcode_found_table <- do.call('cbind',lapply(d.filter.ls,function(x){table(x$status)}))
colnames(barcode_found_table) <- samples
barcode_found_table
# Out:
#                          KI_1_1  KI_1_2  KI_1_3  KI_1_4  KI_1_5
# all barcodes found       1017690 1300173 4394348 7326675 7647358
# barcode missing           258119  316512  652865  970999  963154
# barcode missing P7 found 6285648 6484808 4362984 4300778 3183171

# %%
barcode_found_table_norm <- apply(barcode_found_table,2,function(x){x/sum(x)})
p1 <- ggplot(data = reshape2::melt(barcode_found_table)) + geom_bar(aes(fill = Var1, x = Var2, y = value),stat='identity',position=position_dodge(),col='black') + theme_bw()
p2 <- ggplot(data = reshape2::melt(barcode_found_table_norm)) + geom_bar(aes(fill = Var1, x = Var2, y = value),stat='identity',position=position_dodge(),col='black') + theme_bw()
p1/p2
# Out:
# plot without title

# %%
head(d.filter.ls[[1]])
# Out:
#   V1     V2   V3   V4   V5   V6       V7       V8   status
# 1 read_1 8    None None 32   NACGTGAT CTCATACA None barcode missing P7 found
# 2 read_2 8    None None 40   NACGTGAT AACTGTCT None barcode missing P7 found
# 3 read_3 8    None None None NACGTGAT AACGTGAT None barcode missing
# 4 read_4 None None None 23   None     None     None barcode missing P7 found
# 5 read_5 None None None 33   None     None     None barcode missing P7 found
# 6 read_6 None None None 5    None     None     None barcode missing P7 found
#   P7_distance
# 1 32
# 2 40
# 3 0
# 4 23
# 5 33
# 6 5

# %%
d.filter.ls <- lapply(d.filter.ls, function(x){x$P7_distance <- as.numeric(x$P7_distance);return(x) })

# %%
d.summary.ls     <- lapply(d.filter.ls,function(x){freq <- table(x$P7_distance); 
                                                   fraction <-freq/dim(x)[1]; 
                                                   df <- data.frame(cbind(freq,fraction)); 
                                                   df$l <- as.numeric(rownames(df)); return(df)
                                                  })

# %%
options(repr.plot.width=8, repr.plot.height=4)

lapply(1:length(d.summary.ls),function(x){
    ggplot(data = d.summary.ls[[x]],aes(x = l,y = fraction)) + 
      geom_bar(stat='identity') + 
      theme(axis.text.x = element_text(angle=45)) +
      ggtitle(samples[x]) + theme_base() + coord_cartesian(ylim=c(0,0.8))
    })
# Out:
# plot without title
# plot without title
# plot without title
# [[1]]
#
# [[2]]
#
# [[3]]
#
# [[4]]
#
# [[5]]
# plot without title
# plot without title

# %%
library(rtracklayer)
library(GenomicRanges)
library(gridExtra)
# Out:
# Attaching package: ‘gridExtra’
#
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     combine

# %%
# Out:
# [1] 15

# %%
hist.ls <- lapply(samples,function(s){
  lapply(modalities,function(m){
    fragments.path  <- paste0('/data/proj/GCB_MB/spatial_cut-tag/Yale_Apr_2022_nano_Tn5/results2/',s,'/',m,'/bed/',s,'_fragments.bed')
    fragments.gr    <- rtracklayer::import(fragments.path)
    fragments.width <- width(fragments.gr)
    fragments.width <- data.frame(width=fragments.width[fragments.width < 1500])
    ggplot(data =fragments.width) + geom_histogram(aes(x = width),fill='white',col='black') + theme_bw() + ggtitle(paste(s,m))
    #hist(fragments.width,breaks=seq(0,2000,10))
  })
})

# %%
options(repr.plot.width=15, repr.plot.height=5)
lapply(hist.ls, wrap_plots)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# [[1]]
#
# [[2]]
#
# [[3]]
#
# [[4]]
#
# [[5]]
# plot without title
# plot without title

# %%
fragments.grange.ls <- rtracklayer::import.bed(con='/data/proj/GCB_MB/spatial_cut-tag/Yale_Apr_2022_nano_Tn5/results2/KI_1_4/mod1/bed/KI_1_4_fragments.bed')

# %%
hist_max_cutoff <- quantile(width(f),0.99)
hist(width(f[width(f) < hist_max_cutoff]))
# Out:
# Plot with title “Histogram of width(f[width(f) < hist_max_cutoff])”

# %%
f[width(f) < hist_max_cutoff]
# Out:
# GRanges object with 495017 ranges and 2 metadata columns:
#            seqnames            ranges strand |                   name     score
#               <Rle>         <IRanges>  <Rle> |            <character> <numeric>
#        [1]     chr6 80789104-80789285      * | K00124:727:HHNTCBBXX..        28
#        [2]    chr12 54046845-54046979      * | K00124:727:HHNTCBBXX..        44
#        [3]    chr11 62890672-62891006      * | K00124:727:HHNTCBBXX..        42
#        [4]    chr15 79132301-79132329      * | K00124:727:HHNTCBBXX..        44
#        [5]     chr9 67178452-67178622      * | K00124:727:HHNTCBBXX..        44
#        ...      ...               ...    ... .                    ...       ...
#   [495013]    chr15   3910351-3910457      * | K00124:727:HHNTCBBXX..        14
#   [495014]     chrY 48108818-48108941      * | K00124:727:HHNTCBBXX..        18
#   [495015]     chr2 29512570-29512861      * | K00124:727:HHNTCBBXX..        24
#   [495016]     chr8 71900814-71901222      * | K00124:727:HHNTCBBXX..        11
#   [495017]     chr9 27193908-27194479      * | K00124:727:HHNTCBBXX..        42
#   -------
#   seqinfo: 55 sequences from an unspecified genome; no seqlengths
